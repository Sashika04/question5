# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('complaints.csv')
print(df.head())
# Out:
# /var/folders/g1/tzfr1k0s2sl2hbx4lvv_qrg00000gn/T/ipykernel_51076/1704908100.py:1: DtypeWarning: Columns (16) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('complaints.csv')
#   Date received                                            Product  \
# 0    2025-05-23                                    Debt collection
# 1    2025-05-23                                    Debt collection
# 2    2025-04-18  Credit reporting or other personal consumer re...
# 3    2025-06-08                                    Debt collection
# 4    2025-06-08  Credit reporting or other personal consumer re...
#
#         Sub-product                                              Issue  \
# 0     I do not know                  Attempts to collect debt not owed
# 1  Credit card debt                    Written notification about debt
# 2  Credit reporting               Incorrect information on your report
# 3     I do not know                  Attempts to collect debt not owed
# 4  Credit reporting  Problem with a company's investigation into an...
#
#                                           Sub-issue  \
# 0                 Debt was result of identity theft
# 1  Didn't receive enough information to verify debt
# 2               Information belongs to someone else
# 3                 Debt was result of identity theft
# 4        Problem with personal statement of dispute
#
#   Consumer complaint narrative Company public response  \
# 0                          NaN                     NaN
# 1                          NaN                     NaN
# 2                          NaN                     NaN
# 3                          NaN                     NaN
# 4                          NaN                     NaN
#
#                                Company State ZIP code Tags  \
# 0         CCS Financial Services, Inc.    TX    75006  NaN
# 1          Lockhart Mediation Services    IL    62206  NaN
# 2  Experian Information Solutions Inc.    TX    76114  NaN
# 3                        EQUIFAX, INC.    GA    30296  NaN
# 4                        EQUIFAX, INC.    TX    76542  NaN
#
#   Consumer consent provided? Submitted via Date sent to company  \
# 0                        NaN           Web           2025-05-23
# 1                        NaN           Web           2025-05-23
# 2                        NaN           Web           2025-05-22
# 3                        NaN           Web           2025-06-08
# 4                        NaN           Web           2025-06-08
#
#   Company response to consumer Timely response? Consumer disputed?  \
# 0            Untimely response               No                NaN
# 1            Untimely response               No                NaN
# 2                  In progress              Yes                NaN
# 3                  In progress              Yes                NaN
# 4                  In progress              Yes                NaN
#
#    Complaint ID
# 0      13688046
# 1      13655458
# 2      13049884
# 3      13957561
# 4      13957565

# %%
# Get basic information about the dataset: data types, non-null counts, memory usage
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9408224 entries, 0 to 9408223
# Data columns (total 18 columns):
#  #   Column                        Dtype
# ---  ------                        -----
#  0   Date received                 object
#  1   Product                       object
#  2   Sub-product                   object
#  3   Issue                         object
#  4   Sub-issue                     object
#  5   Consumer complaint narrative  object
#  6   Company public response       object
#  7   Company                       object
#  8   State                         object
#  9   ZIP code                      object
#  10  Tags                          object
#  11  Consumer consent provided?    object
#  12  Submitted via                 object
#  13  Date sent to company          object
#  14  Company response to consumer  object
#  15  Timely response?              object
#  16  Consumer disputed?            object
#  17  Complaint ID                  int64
# dtypes: int64(1), object(17)
# memory usage: 1.3+ GB
# None

# %%
# Summary statistics for numerical columns
print(df.describe())
# Out:
#        Complaint ID
# count  9.408224e+06
# mean   7.963796e+06
# std    3.709877e+06
# min    1.000000e+00
# 25%    4.922783e+06
# 50%    8.326272e+06
# 75%    1.111860e+07
# max    1.396403e+07

# %%
# Check for missing values in each column
print(df.isnull().sum())
# Out:
# Date received                         0
# Product                               0
# Sub-product                      235295
# Issue                                 6
# Sub-issue                        837100
# Consumer complaint narrative    6474487
# Company public response         4671635
# Company                               0
# State                             54276
# ZIP code                          30228
# Tags                            8784880
# Consumer consent provided?      1625136
# Submitted via                         0
# Date sent to company                  0
# Company response to consumer         20
# Timely response?                      0
# Consumer disputed?              8639924
# Complaint ID                          0
# dtype: int64

# %%
# Check for duplicate rows
print(f"Number of duplicate rows: {df.duplicated().sum()}")
# Out:
# Number of duplicate rows: 0

# %%
categorical_cols = ['Product','Sub-product','Issue','Sub-issue','Company complaint narrative','Company public response','Company','State','ZIP code','Tags','Consumer consent provided?','Submitted via','Company response to consumer','Timely response?','Consumer disputed?']

for col in categorical_cols:
    if col in df.columns:
        print(f"Unique values in '{col}':")
        print(df[col].unique())
        print('-' * 40)
# Out:
# Unique values in 'Product':
# ['Debt collection' 'Credit reporting or other personal consumer reports'
#  'Money transfer, virtual currency, or money service' 'Mortgage'
#  'Checking or savings account' 'Credit card' 'Vehicle loan or lease'
#  'Prepaid card' 'Debt or credit management' 'Student loan'
#  'Payday loan, title loan, personal loan, or advance loan'
#  'Credit reporting, credit repair services, or other personal consumer reports'
#  'Consumer Loan' 'Credit card or prepaid card' 'Bank account or service'
#  'Payday loan' 'Credit reporting'
#  'Payday loan, title loan, or personal loan' 'Money transfers'
#  'Other financial service' 'Virtual currency']
# ----------------------------------------
# Unique values in 'Sub-product':
# ['I do not know' 'Credit card debt' 'Credit reporting' 'Virtual currency'
#  'Conventional home mortgage' 'Reverse mortgage' 'FHA mortgage'
#  'Other debt' 'Checking account' 'Mobile or digital wallet'
#  'Store credit card' 'Loan' 'Foreign currency exchange' 'Auto debt'
#  'General-purpose prepaid card' 'Domestic (US) money transfer'
#  'General-purpose credit card or charge card' 'Debt settlement'
#  'Other banking product or service' 'Other personal consumer report'
#  'Credit repair services' 'Medical debt' 'Telecommunications debt'
#  'Private student loan' 'International money transfer' 'Mortgage debt'
#  'Savings account' 'Personal line of credit' 'Private student loan debt'
#  'Federal student loan servicing' 'Rental debt' 'Installment loan'
#  'Payday loan debt' 'Payday loan' 'Other type of mortgage'
#  'Government benefit card' 'Title loan'
#  'Home equity loan or line of credit (HELOC)' 'Federal student loan debt'
#  'Other advances of future income'
#  "Money order, traveler's check or cashier's check" 'USDA mortgage'
#  'Lease' 'Payroll card' 'VA mortgage' 'CD (Certificate of Deposit)'
#  'Mortgage modification or foreclosure avoidance' 'Check cashing service'
#  nan 'Manufactured home loan' 'Gift card' 'Earned wage access' 'Pawn loan'
#  'Other mortgage' 'Student loan debt relief' 'Conventional fixed mortgage'
#  'Conventional adjustable mortgage (ARM)' 'Credit card' 'Medical'
#  'Other (i.e. phone, health club, etc.)' 'Vehicle loan'
#  '(CD) Certificate of deposit' 'Federal student loan'
#  'Other bank product/service' 'Vehicle lease' 'Non-federal student loan'
#  'Mortgage' 'Home equity loan or line of credit' 'Second mortgage'
#  'Refund anticipation check' 'General purpose card' 'Auto'
#  'Student prepaid card' 'Tax refund anticipation loan or check'
#  'Other special purpose card' 'Cashing a check without an account'
#  'Mobile wallet' 'Government benefit payment card'
#  "Traveler's check or cashier's check" 'Gift or merchant card'
#  'Money order' 'Check cashing' 'Credit repair' 'ID prepaid card'
#  'Electronic Benefit Transfer / EBT card' 'Traveler’s/Cashier’s checks'
#  'Transit card']
# ----------------------------------------
# Unique values in 'Issue':
# ['Attempts to collect debt not owed' 'Written notification about debt'
#  'Incorrect information on your report'
#  "Problem with a company's investigation into an existing problem"
#  'Improper use of your report'
#  'Credit monitoring or identity theft protection services' 'Fraud or scam'
#  'Communication tactics'
#  'Unable to get your credit report or credit score'
#  'False statements or representation' 'Trouble during payment process'
#  'Closing on a mortgage' 'Problem caused by your funds being low'
#  'Unauthorized transactions or other transaction problem'
#  'Fees or interest'
#  'Problem with a lender or other company charging your account'
#  'Getting a loan or lease'
#  'Threatened to contact someone or share information improperly'
#  'Managing an account' 'Confusing or misleading advertising or marketing'
#  'Managing the loan or lease' 'Trouble using the card'
#  'Took or threatened to take negative or legal action'
#  'Problem with a purchase shown on your statement' 'Opening an account'
#  "Problem with a company's investigation into an existing issue"
#  'Confusing or missing disclosures' "Didn't provide services promised"
#  'Charged upfront or unexpected fees' 'Getting a credit card'
#  'Problem with a purchase or transfer' 'Struggling to pay mortgage'
#  'Dealing with your lender or servicer' 'Other transaction problem'
#  'Closing an account' 'Problem when making payments'
#  'Money was not available when promised' 'Electronic communications'
#  'Unexpected or other fees' 'Repossession' 'Getting the loan'
#  'Problem with customer service'
#  'Problems at the end of the loan or lease'
#  'Problem with fraud alerts or security freezes'
#  'Struggling to pay your loan' 'Issue with income share agreement'
#  "Charged fees or interest you didn't expect"
#  'Applying for a mortgage or refinancing an existing mortgage'
#  'Closing your account'
#  'Trouble accessing funds in your mobile or digital wallet'
#  'Other features, terms, or problems'
#  'Problem with additional add-on products or services'
#  'Advertising and marketing, including promotional offers'
#  "Received a loan you didn't apply for" 'Trouble using your card'
#  'Other service problem'
#  'Problem with the payoff process at the end of the loan'
#  'Getting a line of credit'
#  'Managing, opening, or closing your mobile wallet account'
#  'Problem adding money' 'Struggling to pay your bill' 'Unexpected fees'
#  'Struggling to repay your loan'
#  "Loan payment wasn't credited to your account"
#  'Identity theft protection or other monitoring services'
#  'Lost or stolen money order' 'Incorrect exchange rate'
#  'Unauthorized withdrawals or charges'
#  'Problem getting a card or closing an account' 'Credit determination'
#  'Overdraft, savings, or rewards features'
#  "Was approved for a loan, but didn't receive the money"
#  'Vehicle was damaged or destroyed the vehicle'
#  'Money was taken from your bank account on the wrong day or for the wrong amount'
#  'Vehicle was repossessed or sold the vehicle'
#  'Wrong amount charged or received' 'Getting a loan' 'Advertising' 'Other'
#  "Can't contact lender or servicer" 'Issues with repayment'
#  'Problem with cash advance'
#  "Can't stop withdrawals from your bank account"
#  'Problems receiving the advance' 'Issue where my lender is my school'
#  "Problem with a credit reporting company's investigation into an existing problem"
#  'Loan modification,collection,foreclosure'
#  'Loan servicing, payments, escrow account'
#  "Cont'd attempts collect debt not owed" 'Shopping for a line of credit'
#  'Closing/Cancelling account' 'Delinquent account'
#  'Problems caused by my funds being low' "Can't contact lender"
#  'Unable to get credit report/credit score'
#  'Incorrect information on credit report'
#  'Account opening, closing, or management' 'Billing disputes'
#  'Settlement process and costs' 'APR or interest rate'
#  'Deposits and withdrawals' 'Late fee' "Can't repay my loan"
#  "Credit reporting company's investigation" 'Problem with overdraft'
#  'Collection debt dispute' 'Problems when you are unable to pay'
#  'Dealing with my lender or servicer' 'Disclosure verification of debt'
#  'Credit monitoring or identity protection'
#  'Credit line increase/decrease' 'Rewards'
#  'Making/receiving payments, sending money'
#  'Credit decision / Underwriting' 'Identity theft / Fraud / Embezzlement'
#  'Application, originator, mortgage broker' 'Credit reporting'
#  'Payoff process' 'Taking/threatening an illegal action'
#  'Customer service / Customer relations' 'Transaction issue' 'Other fee'
#  'Sale of account' 'Using a debit or ATM card' 'Repaying your loan'
#  'Improper use of my credit report' 'Improper contact or sharing of info'
#  'Billing statement' "Charged fees or interest I didn't expect"
#  'Other transaction issues' 'Advertising and marketing'
#  'Collection practices' 'Balance transfer'
#  'Unsolicited issuance of credit card' 'Lost or stolen check'
#  'Unauthorized transactions/trans. issues'
#  "Was approved for a loan, but didn't receive money"
#  'Credit limit changed' 'Shopping for a loan or lease'
#  "Received a loan I didn't apply for"
#  'Advertising, marketing or disclosures'
#  'Credit card protection / Debt protection' 'Taking out the loan or lease'
#  'Cash advance fee' 'Arbitration' 'Balance transfer fee'
#  'Managing the line of credit' 'Account terms and changes'
#  'Lost or stolen refund' 'Cash advance'
#  'Managing, opening, or closing account' 'Other service issues'
#  'Application processing delay' "Can't stop charges to bank account"
#  'Payment to acct not credited' 'Problem with an overdraft'
#  'Excessive fees' 'Charged bank acct wrong day or amt' 'Disclosures'
#  'Applied for loan/did not receive money' 'Unexpected/Other fees'
#  'Forbearance / Workout plans' 'Overlimit fee' 'Fees'
#  'Overdraft, savings or rewards features'
#  'Customer service/Customer relations' 'Privacy' 'Convenience checks'
#  'Incorrect/missing disclosures or info' 'Adding money' 'Bankruptcy'
#  'Property was sold' 'Lender repossessed or sold the vehicle'
#  'Problem with credit report or credit score'
#  'Lender damaged or destroyed vehicle'
#  'Property was damaged or destroyed property' 'Lender sold the property'
#  'Lender damaged or destroyed property' nan]
# ----------------------------------------
# Unique values in 'Sub-issue':
# ['Debt was result of identity theft'
#  "Didn't receive enough information to verify debt"
#  'Information belongs to someone else'
#  'Problem with personal statement of dispute'
#  'Account information incorrect' 'Account status incorrect'
#  'Their investigation did not fix an error on your report'
#  "Credit inquiries on your report that you don't recognize"
#  'Reporting company used your report improperly'
#  'Investigation took more than 30 days' 'Personal information incorrect'
#  'Difficulty submitting a dispute or getting information about a dispute over the phone'
#  "Didn't receive services that were advertised" nan 'Debt is not yours'
#  'Was not notified of investigation status or results'
#  'Old information reappears or never goes away'
#  'Received unwanted marketing or advertising'
#  'You told them to stop contacting you, but they keep trying'
#  'Other problem getting your report or credit score'
#  'Attempted to collect wrong amount' 'Fees charged'
#  'Delays with the closing process' 'Private mortgage insurance (PMI)'
#  'Overdrafts and overdraft fees' 'Problem with fees'
#  'Transaction was not authorized' 'Credit denial'
#  'Talked to a third-party about your debt' 'Banking errors'
#  'Problem using a debit or ATM card'
#  'Problem with additional products or services purchased with the loan'
#  'Trouble using the card to spend money in a store or online'
#  'Threatened or suggested your credit would be damaged' 'Debt was paid'
#  'Called before 8am or after 9pm' 'Public record information inaccurate'
#  "Credit card company isn't resolving a dispute about a purchase on your statement"
#  'Problem accessing account' 'Contacted you after you asked them to stop'
#  'Frequent or repeated calls' 'Unable to open an account'
#  'Unexpected increase in interest rate'
#  'Problem getting your free annual credit report'
#  'Billing dispute for services'
#  'Information is missing that should be on the report'
#  'Card opened without my consent or knowledge'
#  "Didn't receive notice of right to dispute"
#  'Charged for a purchase or transfer you did not make with the card'
#  'Applying for or obtaining a modification, forbearance plan, short sale, or deed-in-lieu'
#  'Trying to communicate with the company to fix an issue related to modification, forbearance, short sale, deed-in-lieu, bankruptcy, or foreclosure'
#  'Trying to communicate with the company to fix an issue while managing or servicing your loan'
#  'Received bad information about your loan' 'Deposits and withdrawals'
#  "Notification didn't disclose it was an attempt to collect a debt"
#  'Problem canceling credit monitoring or identify theft protection service'
#  'Seized or attempted to seize your property'
#  'Funds not received from closed account'
#  'Problem making or receiving payments' 'Frequent or repeated messages'
#  'Used obscene, profane, or other abusive language'
#  'Funds not handled or disbursed as instructed' 'Billing problem'
#  'Foreclosure'
#  'Debt was already discharged in bankruptcy and is no longer owed'
#  'Damage caused or loss of personal items in vehicle during the actual repossession'
#  'Problem during payment process'
#  'Threatened to sue you for very old debt'
#  'Unable to receive car title or other problem after the loan is paid off'
#  'Payment process' 'Loan sold or transferred to another company'
#  'Sued you in a state where you do not live or did not sign for the debt'
#  'Charged too much interest'
#  'Dealing with provider of income share agreement' 'Late or other fees'
#  "Don't agree with the fees charged" 'Cashing a check'
#  'Confusing or misleading advertising or marketing'
#  'Escrow, taxes, or insurance' "Can't close your account"
#  'Card was charged for something you did not purchase with the card'
#  'Other problem'
#  'Confusing or misleading advertising about the credit card'
#  'Trying to communicate with the company to fix an issue with the application process'
#  'Company closed your account'
#  'Account reinstatement or redemption after repossession'
#  'Impersonated attorney, law enforcement, or government official'
#  "Didn't receive terms that were advertised"
#  'Company communicating payment assistance or payment extension options'
#  'Problem with customer service' 'Application denials'
#  'Notice to repossess' 'Problem with product or service terms changing'
#  'Information is incorrect'
#  'Report provided to employer without your written authorization'
#  'Overcharged for something you did purchase with the card'
#  'Indicated you were committing crime by not paying debt'
#  "Didn't receive advertised or promotional terms"
#  'Sued you without properly notifying you of lawsuit'
#  'Received unsolicited financial product or insurance offers after opting out'
#  'Fee problem' "Can't use card to make purchases"
#  'Problem with rewards from credit card' 'Voluntary repossession'
#  'Loan opened without my consent or knowledge'
#  'Problem while selling or giving up the vehicle'
#  'Told you not to respond to a lawsuit they filed against you'
#  'Threatened to arrest you or take you to jail if you do not pay'
#  'Loan balance remaining after the vehicle is repossessed and sold'
#  'Lender trying to repossess or disable the vehicle'
#  'Changes in loan terms during or after closing'
#  'Problem with the interest rate' 'Contacted before 8am or after 9pm'
#  'Problem with paying off the loan'
#  'Account opened without my consent or knowledge'
#  "Card company isn't resolving a dispute about a purchase or transfer"
#  'Denied request to lower payments' 'Sent card you never applied for'
#  'Trouble with how payments are being handled'
#  'Deficiency balance after repossession' 'Problem related to refinancing'
#  'Confusing or missing disclosures'
#  'Non-sufficient funds and associated fees' 'Application denied'
#  'Problem with direct deposit'
#  'Problem getting a working replacement card'
#  "Credit card company won't work with you while you're going through financial hardship"
#  'Setting up an escrow account for taxes and insurance'
#  'Company explaining amount owed' 'Problem with your payment plan'
#  "Credit card company won't increase or decrease your credit limit"
#  'Problem with fees charged'
#  'Trying to communicate with the company to fix an issue with the loan closing'
#  'Collected or attempted to collect exempt funds'
#  'Closing disclosure or other related disclosures'
#  'Problem with forgiveness, cancellation, or discharge'
#  'Contacted your employer' 'Bounced checks or returned payments'
#  'Trouble getting information about the card'
#  'You never received your bill or did not know a payment was due'
#  'Problem lowering your monthly payments'
#  'Need information about your loan balance or loan terms'
#  "Can't temporarily delay making payments"
#  'Termination fees or other problem when ending the lease early'
#  "Can't get other flexible options for repaying your loan"
#  'Delays in the application process'
#  'Trouble using the card to send money to another person'
#  'Changes in terms mid-deal or after closing' 'Co-signer'
#  'Delay in processing application' 'Privacy issues'
#  'Deposits or withdrawals'
#  'Trouble getting, activating, or registering a card'
#  'Paying off the loan'
#  'An existing modification, forbearance plan, short sale, or other loss mitigation relief'
#  'Money was taken from your account on the wrong day or for the wrong amount'
#  'Interest rate' 'Problem with signing the paperwork'
#  'Problem with balance transfer'
#  'Excess mileage, damage, or wear fees, or other problem after the lease is finished'
#  'Trouble getting a working replacement card'
#  'Fees charged for closing account'
#  'Changes in loan terms during the application process'
#  'High-pressure sales tactics'
#  'Problem after you declared or threatened to declare bankruptcy'
#  "Can't stop withdrawals from your account"
#  'Fees or costs during the application process' 'Problem with renewal'
#  'Impersonated an attorney or official' 'Fees or costs after closing'
#  'High pressure sales tactics or recruiting'
#  'Confusing or misleading advertising about the card'
#  'Problem with additional add-on products or services purchased with the loan'
#  'Account sold or transferred to another company'
#  'Information that should be on the report is missing'
#  'Problem with fees or penalties'
#  'Problem using the card to withdraw money from an ATM' 'Lien release'
#  'Confusing or misleading advertising' 'Trouble closing card'
#  'Add-on products and services'
#  'Changes in terms from what was offered or advertised'
#  'Keep getting calls about your loan' 'Problem with a trade-in'
#  'Billing or statement issues' 'Bankruptcy'
#  'Problem with convenience check' 'Issues with fees connected to the loan'
#  'Loan estimate or other related disclosures'
#  'Credit card company forcing arbitration' 'Filed for bankruptcy'
#  'Problem with cash advances'
#  "Don't want a card provided by your employer or the government"
#  'Did not receive car title' 'Trouble using the card to pay a bill'
#  'Payment issues' 'Debt is not mine'
#  'Problem getting report or credit score' 'Account status' 'Public record'
#  'Information is not mine' "Can't decrease my monthly payments"
#  'No notice of investigation status/result' 'Personal information'
#  "Was signed up for overdraft on card, but don't want to be"
#  'Called outside of 8am-9pm' 'Investigation took too long'
#  'Debt resulted from identity theft' "Don't agree with fees charged"
#  'Problem getting my free annual report' 'Account terms'
#  'Inadequate help over the phone' 'Not given enough info to verify debt'
#  'Problem extending the lease' 'Problem with fraud alerts'
#  "Can't get flexible payment options"
#  'Trouble with how payments are handled'
#  'Seized/Attempted to seize property' 'Keep getting calls about my loan'
#  'Received bad information about my loan'
#  'Threatened arrest/jail if do not pay'
#  'Cannot graduate, receive diploma, or get transcript due to money owed'
#  'Problem with statement of dispute'
#  'Sued w/o proper notification of suit'
#  'Issues with financial aid services' 'Threatened to take legal action'
#  'Reinserted previously deleted info' 'Report improperly shared by CRC'
#  'Contacted me instead of my attorney' 'Threatened to sue on too old debt'
#  'Contacted me after I asked not to'
#  'Talked to a third party about my debt'
#  'Need information about my balance/terms' 'Account terms and changes'
#  "Can't temporarily postpone payments"
#  'Negative impact of inaccurate appraisal'
#  'Overcharged for a purchase or transfer you did make with the card'
#  'Account opened as a result of fraud' 'Marketing or disclosure issues'
#  'Debt was discharged in bankruptcy' 'Denied loan'
#  'Contacted you instead of your attorney'
#  'Not disclosed as an attempt to collect'
#  'Threatened to turn you in to immigration or deport you'
#  'Fraudulent loan' 'Problem adding money'
#  'Having problems with customer service'
#  'Problem cancelling or closing account'
#  "Indicated shouldn't respond to lawsuit"
#  'Problem when attempting to purchase vehicle at the end of the lease'
#  'Card opened as result of identity theft or fraud'
#  'Used obscene/profane/abusive language'
#  'Contacted employer after asked not to'
#  'Called after sent written cease of comm'
#  'Right to dispute notice not received' 'Overdraft charges'
#  'Qualify for a better loan than offered'
#  'Indicated committed crime not paying'
#  'Report shared with employer w/o consent' "Can't qualify for a loan"
#  'Attempted to/Collected exempt funds' 'Billing dispute'
#  'Received marketing offer after opted out'
#  "Sued where didn't live/sign for debt"
#  'Qualified for a better loan than the one offered'
#  'Receiving unwanted marketing/advertising'
#  'Problem with a check written from your prepaid card account'
#  'Insurance terms' 'Incorrect information on your report'
#  "Problem with a credit reporting company's investigation into an existing problem"
#  'Credit monitoring or identity theft protection services'
#  'Problem with fraud alerts or security freezes'
#  'Improper use of your report']
# ----------------------------------------
# Unique values in 'Company public response':
# [nan
#  'Company has responded to the consumer and the CFPB and chooses not to provide a public response'
#  'Company disputes the facts presented in the complaint'
#  'Company believes it acted appropriately as authorized by contract or law'
#  'Company believes complaint is the result of an isolated error'
#  'Company believes complaint caused principally by actions of third party outside the control or direction of the company'
#  'Company believes complaint represents an opportunity for improvement to better serve consumers'
#  "Company believes the complaint provided an opportunity to answer consumer's questions"
#  'Company believes the complaint is the result of a misunderstanding'
#  "Company can't verify or dispute the facts in the complaint"
#  'Company chooses not to provide a public response'
#  'Company believes complaint relates to a discontinued policy or procedure']
# ----------------------------------------
# Unique values in 'Company':
# ['CCS Financial Services, Inc.' 'Lockhart Mediation Services'
#  'Experian Information Solutions Inc.' ... 'Freeborn & Peters LLP'
#  'TASO Group LLC' 'Credit Points 720']
# ----------------------------------------
# Unique values in 'State':
# ['TX' 'IL' 'GA' 'FL' 'MI' 'TN' 'NC' 'NY' 'NJ' 'CA' 'SC' 'NV' 'PA' 'LA'
#  'MD' 'MS' 'UT' 'MA' 'IN' 'CT' 'MO' 'KS' 'WA' 'OH' 'OK' 'CO' 'HI' 'DC'
#  'AL' 'VA' 'WI' 'AP' 'AZ' 'NM' nan 'WV' 'AR' 'KY' 'PR' 'DE' 'MN' 'RI' 'IA'
#  'SD' 'AE' 'OR' 'ID' 'NH' 'NE' 'ME' 'VT' 'AK' 'ND' 'WY' 'MT' 'VI' 'AS'
#  'GU' 'MP' 'UNITED STATES MINOR OUTLYING ISLANDS' 'AA' 'FM' 'PW' 'MH']
# ----------------------------------------
# Unique values in 'ZIP code':
# ['75006' '62206' '76114' ... '16235' '44525' '04547']
# ----------------------------------------
# Unique values in 'Tags':
# [nan 'Servicemember' 'Older American' 'Older American, Servicemember']
# ----------------------------------------
# Unique values in 'Consumer consent provided?':
# [nan 'Consent not provided' 'Consent provided' 'Other' 'Consent withdrawn']
# ----------------------------------------
# Unique values in 'Submitted via':
# ['Web' 'Referral' 'Phone' 'Postal mail' 'Fax' 'Email' 'Web Referral']
# ----------------------------------------
# Unique values in 'Company response to consumer':
# ['Untimely response' 'In progress' 'Closed with explanation'
#  'Closed with non-monetary relief' 'Closed with monetary relief'
#  'Closed without relief' 'Closed' 'Closed with relief' nan]
# ----------------------------------------
# Unique values in 'Timely response?':
# ['No' 'Yes']
# ----------------------------------------
# Unique values in 'Consumer disputed?':
# [nan 'No' 'Yes']
# ----------------------------------------

# %%
# Drop columns with more than 50% missing values
threshold = len(df) * 0.5
df = df.dropna(axis=1, thresh=threshold)

# %%
print(df.isnull().sum())
# Out:
# Date received                         0
# Product                               0
# Sub-product                      235295
# Issue                                 6
# Sub-issue                        837100
# Company public response         4671635
# Company                               0
# State                             54276
# ZIP code                          30228
# Consumer consent provided?      1625136
# Submitted via                         0
# Date sent to company                  0
# Company response to consumer         20
# Timely response?                      0
# Complaint ID                          0
# dtype: int64

# %%
# Impute missing values in categorical columns with the most frequent value
from sklearn.impute import SimpleImputer

for col in categorical_cols:
    if col in df.columns:
        imputer = SimpleImputer(strategy='most_frequent')
        # Use .ravel() to flatten the 2D array to 1D 
        df[col] = imputer.fit_transform(df[[col]]).ravel()

# %%
print(df.isnull().sum())
# Out:
# Date received                   0
# Product                         0
# Sub-product                     0
# Issue                           0
# Sub-issue                       0
# Company public response         0
# Company                         0
# State                           0
# ZIP code                        0
# Consumer consent provided?      0
# Submitted via                   0
# Date sent to company            0
# Company response to consumer    0
# Timely response?                0
# Complaint ID                    0
# dtype: int64

# %%
# Get number of rows and columns
rows, columns = df.shape
print(f"Number of rows: {rows}")
print(f"Number of columns: {columns}")
# Out:
# Number of rows: 9408224
# Number of columns: 15

# %%
product_mapping = {
    'Credit reporting or other personal consumer report': 0,
    'Debt collection': 1,
    'Consumer Loan': 2,
    'Mortgage': 3
}
df['Category'] = df['Product'].map(product_mapping)
df = df.dropna(subset=['Category'])
df['Category'] = df['Category'].astype(int)

# %%
df['text'] = df['Issue'].fillna('') + ' ' + df['Sub-issue'].fillna('')

# %%
import re

def clean_text(text):
    text = text.lower()
    text = re.sub(r'[^a-zA-Z\s]', '', text)  # Remove non-letter characters
    text = re.sub(r'\s+', ' ', text).strip() # Remove extra spaces
    return text

df['cleaned_text'] = df['text'].apply(clean_text)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
import joblib

vectorizer = TfidfVectorizer(stop_words='english', max_features=5000)
X_text = vectorizer.fit_transform(df['cleaned_text'])

# During training, after fitting the vectorizer:
joblib.dump(vectorizer, 'tfidf_vectorizer.pkl') # Save the vectorizer
# Out:
# ['tfidf_vectorizer.pkl']

# %%
print(df.head())
# Out:
#     Date received          Product       Sub-product  \
# 0      2025-05-23  Debt collection     I do not know
# 1      2025-05-23  Debt collection  Credit card debt
# 3      2025-06-08  Debt collection     I do not know
# 88     2025-06-07  Debt collection     I do not know
# 143    2025-05-10  Debt collection  Credit card debt
#
#                                  Issue  \
# 0    Attempts to collect debt not owed
# 1      Written notification about debt
# 3    Attempts to collect debt not owed
# 88   Attempts to collect debt not owed
# 143              Communication tactics
#
#                                              Sub-issue  \
# 0                    Debt was result of identity theft
# 1     Didn't receive enough information to verify debt
# 3                    Debt was result of identity theft
# 88                                   Debt is not yours
# 143  You told them to stop contacting you, but they...
#
#                                Company public response  \
# 0    Company has responded to the consumer and the ...
# 1    Company has responded to the consumer and the ...
# 3    Company has responded to the consumer and the ...
# 88   Company has responded to the consumer and the ...
# 143  Company has responded to the consumer and the ...
#
#                                  Company State ZIP code  \
# 0           CCS Financial Services, Inc.    TX    75006
# 1            Lockhart Mediation Services    IL    62206
# 3                          EQUIFAX, INC.    GA    30296
# 88   Experian Information Solutions Inc.    GA    30606
# 143                 ZWICKER & ASSOCIATES    TX    78254
#
#     Consumer consent provided? Submitted via Date sent to company  \
# 0         Consent not provided           Web           2025-05-23
# 1         Consent not provided           Web           2025-05-23
# 3         Consent not provided           Web           2025-06-08
# 88        Consent not provided           Web           2025-06-07
# 143       Consent not provided           Web           2025-05-22
#
#     Company response to consumer Timely response?  Complaint ID  Category  \
# 0              Untimely response               No      13688046         1
# 1              Untimely response               No      13655458         1
# 3                    In progress              Yes      13957561         1
# 88                   In progress              Yes      13948863         1
# 143      Closed with explanation              Yes      13446430         1
#
#                                                   text  \
# 0    Attempts to collect debt not owed Debt was res...
# 1    Written notification about debt Didn't receive...
# 3    Attempts to collect debt not owed Debt was res...
# 88   Attempts to collect debt not owed Debt is not ...
# 143  Communication tactics You told them to stop co...
#
#                                           cleaned_text
# 0    attempts to collect debt not owed debt was res...
# 1    written notification about debt didnt receive ...
# 3    attempts to collect debt not owed debt was res...
# 88   attempts to collect debt not owed debt is not ...
# 143  communication tactics you told them to stop co...

# %%
print(df.shape)
# Out:
# (1241493, 18)

# %%
from sklearn.model_selection import train_test_split
# Target variable
y = df['Category']

X_train, X_test, y_train, y_test = train_test_split(
    X_text, y, test_size=0.3, random_state=42, stratify=y
)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.svm import LinearSVC
import warnings
import joblib
warnings.filterwarnings("ignore")

models = {
    'Logistic Regression': LogisticRegression(max_iter=1000,penalty='l1', solver='liblinear', C=0.0001),
    'Multinomial Naive Bayes': MultinomialNB(alpha=1000.0),
    'Linear SVC': LinearSVC(C=0.001, tol=1, max_iter=1000)
}

for name, model in models.items():
    model.fit(X_train, y_train)
    print(f"{name} trained.")

joblib.dump(models['Logistic Regression'], 'logistic_regression_model.pkl')
joblib.dump(models['Multinomial Naive Bayes'], 'multinomial_nb_model.pkl')
joblib.dump(models['Linear SVC'], 'linear_svc_model.pkl')
# Out:
# Logistic Regression trained.
# Multinomial Naive Bayes trained.
# Linear SVC trained.
# ['linear_svc_model.pkl']

# %%
from sklearn.metrics import classification_report, accuracy_score

for name, model in models.items():
    y_pred = model.predict(X_test)
    print(f"--- {name} ---")
    print("Accuracy:", accuracy_score(y_test, y_pred))
    print(classification_report(y_test, y_pred))
# Out:
# --- Logistic Regression ---
# Accuracy: 0.9398520061860984
#               precision    recall  f1-score   support
#
#            1       0.95      1.00      0.97    236563
#            2       0.00      0.00      0.00      9472
#            3       0.92      0.90      0.91    126413
#
#     accuracy                           0.94    372448
#    macro avg       0.62      0.63      0.63    372448
# weighted avg       0.92      0.94      0.93    372448
#
# --- Multinomial Naive Bayes ---
# Accuracy: 0.9743991107483461
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00    236563
#            2       0.00      0.00      0.00      9472
#            3       0.93      1.00      0.96    126413
#
#     accuracy                           0.97    372448
#    macro avg       0.64      0.67      0.65    372448
# weighted avg       0.95      0.97      0.96    372448
#
# --- Linear SVC ---
# Accuracy: 0.9693541111779362
#               precision    recall  f1-score   support
#
#            1       0.99      1.00      1.00    236563
#            2       0.00      0.00      0.00      9472
#            3       0.93      0.98      0.96    126413
#
#     accuracy                           0.97    372448
#    macro avg       0.64      0.66      0.65    372448
# weighted avg       0.95      0.97      0.96    372448

# %%
import pandas as pd

sample_data = pd.DataFrame({
    'Issue': [
        'Attempts to collect debt not owed',
        'Incorrect information on your report',
        'Communication tactics'
    ],
    'Sub-issue': [
        'Debt was result of identity theft',
        'Information belongs to someone else',
        'You told them to stop contacting you, but they continue'
    ],
    'Company public response': [
        'Company has responded to the consumer and the CFPB',
        'Company has responded to the consumer and the CFPB',
        'Company has responded to the consumer and the CFPB'
    ],
    'Company': [
        'CCS Financial Services, Inc.',
        'Experian Information Solutions Inc.',
        'ZWICKER & ASSOCIATES'
    ],
    'State': ['TX', 'TX', 'TX'],
    'ZIP code': ['75006', '76114', '78254'],
    'Consumer consent provided?': [
        'Consent not provided',
        'Consent not provided',
        'Consent not provided'
    ],
    'Submitted via': ['Web', 'Web', 'Web'],
    'Date sent to company': ['2025-05-23', '2025-05-22', '2025-05-22'],
    'Company response to consumer': [
        'Untimely response',
        'In progress',
        'Closed with explanation'
    ],
    'Timely response?': ['No', 'Yes', 'Yes'],
    'Complaint ID': [13688046, 13049884, 13446430],
    'Category': [1, 0, 1],  # Use only for evaluation, not for prediction
    'text': [
        'Attempts to collect debt not owed Debt was result of identity theft',
        'Incorrect information on your report Information belongs to someone else',
        'Communication tactics You told them to stop contacting you, but they continue'
    ],
    'cleaned_text': [
        'attempts to collect debt not owed debt was result of identity theft',
        'incorrect information on your report information belongs to someone else',
        'communication tactics you told them to stop contacting you but they continue'
    ]
})

# %%
vectorizer = joblib.load('tfidf_vectorizer.pkl')
# Use your previously fitted vectorizer
X_new = vectorizer.transform(sample_data['cleaned_text'])

log_reg = joblib.load('logistic_regression_model.pkl')
mnb = joblib.load('multinomial_nb_model.pkl')
svc = joblib.load('linear_svc_model.pkl')

# Use your trained models
log_reg_preds = log_reg.predict(X_new)
mnb_preds = mnb.predict(X_new)
svc_preds = svc.predict(X_new)

# %%
print("Logistic Regression predictions:", log_reg_preds)
print("MultinomialNB predictions:", mnb_preds)
print("LinearSVC predictions:", svc_preds)
# Out:
# Logistic Regression predictions: [1 3 1]
# MultinomialNB predictions: [1 3 1]
# LinearSVC predictions: [1 3 1]
